# %%
import pandas as pd, numpy as np, seaborn as sns, matplotlib.pyplot as plt

# %%
df = pd.read_csv('loan.csv')
# Out:
# C:\Users\home\AppData\Local\Temp\ipykernel_19892\129683778.py:1: DtypeWarning: Columns (47) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('loan.csv')

# %%
df.shape
# Out:
# (39717, 111)

# %%
df.drop(columns=df.columns[df.isnull().sum()>10000],inplace=True)

# %%
df.isnull().sum()
# Out:
# id                               0
# member_id                        0
# loan_amnt                        0
# funded_amnt                      0
# funded_amnt_inv                  0
# term                             0
# int_rate                         0
# installment                      0
# grade                            0
# sub_grade                        0
# emp_title                     2459
# emp_length                    1075
# home_ownership                   0
# annual_inc                       0
# verification_status              0
# issue_d                          0
# loan_status                      0
# pymnt_plan                       0
# url                              0
# purpose                          0
# title                           11
# zip_code                         0
# addr_state                       0
# dti                              0
# delinq_2yrs                      0
# earliest_cr_line                 0
# inq_last_6mths                   0
# ...

# %%
df.emp_title.fillna(df.emp_title.mode()[0],inplace=True)
df.emp_length.fillna(df.emp_length.mode()[0],inplace=True)

# %%
df.isnull().sum()
# Out:
# id                              0
# member_id                       0
# loan_amnt                       0
# funded_amnt                     0
# funded_amnt_inv                 0
# term                            0
# int_rate                        0
# installment                     0
# grade                           0
# sub_grade                       0
# emp_title                       0
# emp_length                      0
# home_ownership                  0
# annual_inc                      0
# verification_status             0
# issue_d                         0
# loan_status                     0
# pymnt_plan                      0
# url                             0
# purpose                         0
# title                          11
# zip_code                        0
# addr_state                      0
# dti                             0
# delinq_2yrs                     0
# earliest_cr_line                0
# inq_last_6mths                  0
# ...

# %%
df.pub_rec_bankruptcies.fillna(df.pub_rec_bankruptcies.mode()[0],inplace=True)

# %%
df.isnull().sum()
# Out:
# id                             0
# member_id                      0
# loan_amnt                      0
# funded_amnt                    0
# funded_amnt_inv                0
# term                           0
# int_rate                       0
# installment                    0
# grade                          0
# sub_grade                      0
# emp_title                      0
# emp_length                     0
# home_ownership                 0
# annual_inc                     0
# verification_status            0
# issue_d                        0
# loan_status                    0
# pymnt_plan                     0
# url                            0
# purpose                        0
# title                         11
# zip_code                       0
# addr_state                     0
# dti                            0
# delinq_2yrs                    0
# earliest_cr_line               0
# inq_last_6mths                 0
# open_acc                       0
# ...

# %%
df['title'].fillna(df.title.mode()[0],inplace=True)

# %%
df.revol_util.fillna(df.revol_util.mode()[0],inplace=True)

# %%
df.dropna(inplace=True)

# %%
df.drop(columns='collections_12_mths_ex_med',inplace=True)

# %%
df.drop(columns='chargeoff_within_12_mths',inplace=True)

# %%
df.drop(columns='tax_liens',inplace=True)

# %%
df.isnull().sum()
# Out:
# id                         0
# member_id                  0
# loan_amnt                  0
# funded_amnt                0
# funded_amnt_inv            0
# term                       0
# int_rate                   0
# installment                0
# grade                      0
# sub_grade                  0
# emp_title                  0
# emp_length                 0
# home_ownership             0
# annual_inc                 0
# verification_status        0
# issue_d                    0
# loan_status                0
# pymnt_plan                 0
# url                        0
# purpose                    0
# title                      0
# zip_code                   0
# addr_state                 0
# dti                        0
# delinq_2yrs                0
# earliest_cr_line           0
# inq_last_6mths             0
# open_acc                   0
# pub_rec                    0
# revol_bal                  0
# revol_util                 0
# total_acc                  0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39588 entries, 0 to 39665
# Data columns (total 50 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       39588 non-null  int64
#  1   member_id                39588 non-null  int64
#  2   loan_amnt                39588 non-null  int64
#  3   funded_amnt              39588 non-null  int64
#  4   funded_amnt_inv          39588 non-null  float64
#  5   term                     39588 non-null  object
#  6   int_rate                 39588 non-null  object
#  7   installment              39588 non-null  float64
#  8   grade                    39588 non-null  object
#  9   sub_grade                39588 non-null  object
#  10  emp_title                39588 non-null  object
#  11  emp_length               39588 non-null  object
#  12  home_ownership           39588 non-null  object
#  13  annual_inc               39588 non-null  float64
# ...

# %%
df.describe()
# Out:
#                  id     member_id     loan_amnt   funded_amnt  \
# count  3.958800e+04  3.958800e+04  39588.000000  39588.000000
# mean   6.839758e+05  8.515498e+05  11232.417652  10959.801581
# std    2.097303e+05  2.643922e+05   7456.207018   7186.338454
# min    5.473400e+04  7.472400e+04    500.000000    500.000000
# 25%    5.167418e+05  6.673665e+05   5500.000000   5400.000000
# 50%    6.661550e+05  8.515125e+05  10000.000000   9700.000000
# 75%    8.380968e+05  1.047620e+06  15000.000000  15000.000000
# max    1.077501e+06  1.314167e+06  35000.000000  35000.000000
#
#        funded_amnt_inv   installment    annual_inc           dti  \
# count     39588.000000  39588.000000  3.958800e+04  39588.000000
# mean      10416.765224    324.882521  6.898375e+04     13.324571
# std        7125.032599    208.842214  6.383496e+04      6.675743
# min           0.000000     15.690000  4.000000e+03      0.000000
# 25%        5000.000000    167.340000  4.050000e+04      8.190000
# ...

# %%
plt.figure(figsize=[15,7])
sns.boxplot(data=df,x='home_ownership',y='funded_amnt');

# %%
plt.figure(figsize=[15,7])
sns.barplot(data=df,x='home_ownership',y='funded_amnt');

# %%
plt.figure(figsize=[15,7])
sns.barplot(data=df,x='home_ownership',y='funded_amnt');

# %%
plt.figure(figsize=[15,7])
sns.barplot(data=df,x='home_ownership',y='funded_amnt_inv');

# %%
plt.figure(figsize=[15,7])
sns.barplot(data=df,x='home_ownership',y='funded_amnt');

# %%
plt.figure(figsize=[15,7])
sns.barplot(data=df,x='loan_status',y='annual_inc');

# %%
plt.figure(figsize=[15,7])
sns.barplot(data=df,x='home_ownership',y='annual_inc');

# %%
df.pymnt_plan.value_counts()
# Out:
# n    39588
# Name: pymnt_plan, dtype: int64

# %%
df.drop(columns='pymnt_plan',inplace=True)

# %%
plt.figure(figsize=[15,7])
sns.barplot(data=df,x='purpose',y='loan_amnt')
plt.xticks(rotation=90);

# %%
df.emp_title
# Out:
# 0                               US Army
# 1                                 Ryder
# 2                               US Army
# 3                   AIR RESOURCES BOARD
# 4              University Medical Group
#                       ...
# 39661                           Impress
# 39662                           Impress
# 39663                         Starbucks
# 39664     North Greenwich Financial LLC
# 39665    Community Environmental Center
# Name: emp_title, Length: 39588, dtype: object

# %%
df.drop(columns='acc_now_delinq',inplace=True)

# %%
df.delinq_amnt.value_counts()
# Out:
# 0    39588
# Name: delinq_amnt, dtype: int64

# %%
df.drop(columns='delinq_amnt',inplace=True)

# %%
df.application_type.value_counts()
# Out:
# INDIVIDUAL    39588
# Name: application_type, dtype: int64

# %%
df.drop(columns='application_type',inplace=True)

# %%
df.drop(columns='url',inplace=True)

# %%
df.verification_status.value_counts()
# Out:
# Not Verified       16826
# Verified           12789
# Source Verified     9973
# Name: verification_status, dtype: int64

# %%
plt.figure(figsize=[15,7])
sns.boxplot(data=df,x='verification_status',y='loan_amnt');

# %%
plt.rcParams['figure.figsize'] = (15,7)

# %%
sns.boxplot(data=df,x='verification_status',y='annual_inc');

# %%
df['annual_inc'].describe()
# Out:
# count    3.958800e+04
# mean     6.898375e+04
# std      6.383496e+04
# min      4.000000e+03
# 25%      4.050000e+04
# 50%      5.900000e+04
# 75%      8.231100e+04
# max      6.000000e+06
# Name: annual_inc, dtype: float64

# %%
df.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade', 'emp_title',
#        'emp_length', 'home_ownership', 'annual_inc', 'verification_status',
#        'issue_d', 'loan_status', 'purpose', 'title', 'zip_code', 'addr_state',
#        'dti', 'delinq_2yrs', 'earliest_cr_line', 'inq_last_6mths', 'open_acc',
#        'pub_rec', 'revol_bal', 'revol_util', 'total_acc',
#        'initial_list_status', 'out_prncp', 'out_prncp_inv', 'total_pymnt',
#        'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int',
#        'total_rec_late_fee', 'recoveries', 'collection_recovery_fee',
#        'last_pymnt_d', 'last_pymnt_amnt', 'last_credit_pull_d', 'policy_code',
#        'pub_rec_bankruptcies'],
#       dtype='object')

# %%
sns.barplot(data=df,x='grade',y='inq_last_6mths');

# %%
sns.barplot(data=df,x='grade',y='annual_inc');

# %%
sns.scatterplot(data=df,x='loan_amnt',y='annual_inc');

# %%
sns.barplot(data=df,x='addr_state',y='annual_inc');

# %%
df.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade', 'emp_title',
#        'emp_length', 'home_ownership', 'annual_inc', 'verification_status',
#        'issue_d', 'loan_status', 'purpose', 'title', 'zip_code', 'addr_state',
#        'dti', 'delinq_2yrs', 'earliest_cr_line', 'inq_last_6mths', 'open_acc',
#        'pub_rec', 'revol_bal', 'revol_util', 'total_acc',
#        'initial_list_status', 'out_prncp', 'out_prncp_inv', 'total_pymnt',
#        'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int',
#        'total_rec_late_fee', 'recoveries', 'collection_recovery_fee',
#        'last_pymnt_d', 'last_pymnt_amnt', 'last_credit_pull_d', 'policy_code',
#        'pub_rec_bankruptcies'],
#       dtype='object')

# %%
sns.boxplot(data=df,x='home_ownership',y='installment');

# %%
df.int_rate = df.int_rate.apply(lambda x:float(x[:-1]))

# %%
sns.boxplot(data=df,x='verification_status',y='int_rate');

# %%
sns.boxplot(data=df,x='verification_status',y='funded_amnt');

# %%
df.drop(columns='policy_code',inplace=True)

# %%
sns.barplot(data=df,x='emp_length',y='annual_inc');

# %%
sns.scatterplot(data=df,x='total_acc',y='loan_amnt');

# %%
sns.histplot(data=df,x='loan_amnt',y='int_rate')
# Out:
# <AxesSubplot:xlabel='loan_amnt', ylabel='int_rate'>

# %%
sns.scatterplot(data=df,x='loan_amnt',y='total_pymnt');

# %%
sns.scatterplot(data=df,x='funded_amnt_inv',y='total_pymnt_inv');

# %%
sns.boxplot(data=df,x='sub_grade',y='total_rec_prncp');

# %%
sns.boxplot(data=df,x='grade',y='total_rec_prncp');

# %%
df.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade', 'emp_title',
#        'emp_length', 'home_ownership', 'annual_inc', 'verification_status',
#        'issue_d', 'loan_status', 'purpose', 'title', 'zip_code', 'addr_state',
#        'dti', 'delinq_2yrs', 'earliest_cr_line', 'inq_last_6mths', 'open_acc',
#        'pub_rec', 'revol_bal', 'revol_util', 'total_acc',
#        'initial_list_status', 'out_prncp', 'out_prncp_inv', 'total_pymnt',
#        'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int',
#        'total_rec_late_fee', 'recoveries', 'collection_recovery_fee',
#        'last_pymnt_d', 'last_pymnt_amnt', 'last_credit_pull_d',
#        'pub_rec_bankruptcies'],
#       dtype='object')

# %%
sns.heatmap(pd.pivot_table(data=df,index='grade',columns='home_ownership',values='funded_amnt'),annot=True,cmap='RdYlGn');

# %%
sns.heatmap(pd.pivot_table(data=df,index='grade',columns='home_ownership',values='annual_inc'),annot=True,cmap='viridis');

# %%
sns.heatmap(pd.pivot_table(data=df,index='grade',columns='home_ownership',values='installment'),annot=True,cmap='plasma');

# %%
sns.heatmap(pd.pivot_table(data=df,index='purpose',columns='home_ownership',values='annual_inc'),annot=True,cmap='coolwarm');

# %%
sns.heatmap(pd.pivot_table(data=df,index='purpose',columns='grade',values='annual_inc'),annot=True,cmap='RdBu');

# %%
plt.figure(figsize=[35,20])
sns.heatmap(pd.pivot_table(data=df,index='addr_state',columns='grade',values='annual_inc'),annot=True,cmap='hot');

# %%
sns.heatmap(pd.pivot_table(data=df,index='grade',columns='emp_length',values='annual_inc'),annot=True,cmap='RdYlGn');
